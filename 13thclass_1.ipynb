# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline

# %%
pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 16

# %%
from mpl_toolkits import mplot3d
from matplotlib import cm

# %%
def analytical_solution(x, y, Lx, Ly):
    X, Y = numpy.meshgrid(x, y)
    u = (numpy.sinh(1.5 * numpy.pi * Y / Ly) *
         numpy.sin(1.5 * numpy.pi * X / Lx) /
         numpy.sinh(1.5 * numpy.pi * Ly / Lx))
    return u

# %%
Lx, Ly = 1.0, 1.0
nx , ny = 41, 41

x = numpy.linspace(0.0, Lx, num=nx)
y = numpy.linspace(0.0, Ly, num=ny)

ua = analytical_solution(x, y, Lx, Ly)

# %%
def plot_3d(x, y, u):
    fig = pyplot.figure(figsize=(8.0, 6.0))
    ax = mplot3d.Axes3D(fig)
    X, Y = numpy.meshgrid(x, y)
    ax.plot_surface(X, Y, u, cmap=cm.viridis)
    ax.view_init(elev=30.0, azim=45.0)

# %%
plot_3d(x, y, ua)

# %%
def relative_l2_norm(u, u_ref):
    rdiff = (numpy.sqrt(numpy.sum((u - u_ref)**2)) /
             numpy.sqrt(numpy.sum(u_ref**2)))
    return rdiff

# %%
p = [1.0, 1.0]


a = p.copy()
a[0] = 3.0
print(p)
print(a)
# Out:
# [1.0, 1.0]
# [3.0, 1.0]

# %%
def laplace2d_jacobi(u0, rtol=1e-6, maxiter=20000):
    u = u0.copy()
    ite = 0
    rdiff = rtol + 1.0
    while rdiff > rtol and ite < maxiter:
        un = u.copy()
        u[1:-1, 1:-1] = 0.25 * (u[:-2, 1:-1] + u[1:-1, :-2] + 
                                u[1:-1, 2:] + u[2:, 1:-1])
        u[1:-1, -1] = u[1:-1, -2]
        rdiff = relative_l2_norm(u, un)
        ite += 1
    return u, ite, rdiff

# %%
u0 = numpy.zeros((ny, nx))
u0[-1, :] = numpy.sin(1.5 * numpy.pi * x / Lx)
plot_3d(x, y, u0)

# %%
u, ites, rdiff = laplace2d_jacobi(u0, rtol=1e-8)

# %%
print(ites, rdiff)
# Out:
# 4473 9.989253683735693e-09

# %%
plot_3d(x, y, u)

# %%
nx_values = [11, 21, 41, 81]
errors = []

for nx in nx_values:
    print(nx)
    x = numpy.linspace(0.0, Lx, num=nx)
    y = x.copy()
    u0 = numpy.zeros((nx, nx))
    u0[-1, :] = numpy.sin(1.5 * numpy.pi * x / Lx)
    u = laplace2d_jacobi(u0, rtol=1e-8)[0]
    ua = analytical_solution(x, y, Lx, Lx)
    error = relative_l2_norm(u, ua)
    errors.append(error)
# Out:
# 11
# 21
# 41
# 81

# %%
pyplot.figure(figsize=(6.0, 6.0))
pyplot.grid()
dx_values = []
for nx in nx_values:
    dx_values.append(Lx / (nx - 1))
pyplot.loglog(dx_values, errors,
              color='black', linestyle='--', linewidth=2, marker='o')  
pyplot.axis('equal');

# %%
def laplace2d_jacobi_neumann(u0, rtol=1e-6, maxiter=20000):
    u = u0.copy()
    ite = 0
    rdiff = rtol + 1.0
    while rdiff > rtol and ite < maxiter:
        un = u.copy()
        u[1:-1, 1:-1] = 0.25 * (u[:-2, 1:-1] + u[1:-1, :-2] + 
                                u[1:-1, 2:] + u[2:, 1:-1])
        u[1:-1, -1] = 0.25 * (u[:-2, -1] + 2 * u[1:-1, -2] + u[2:, -1])
        rdiff = relative_l2_norm(u, un)
        ite += 1
    return u, ite, rdiff

# %%
nx_values = [11, 21, 41, 81]
errors = []

for nx in nx_values:
    print(nx)
    x = numpy.linspace(0.0, Lx, num=nx)
    y = x.copy()
    u0 = numpy.zeros((nx, ny))
    u0[-1, :] = numpy.sin(1.5 * numpy.pi * x / Lx)
    u = laplace2d_jacobi_neumann(u0, rtol=1e-8)[0]
    ua = analytical_solution(x, y, Lx, Lx)
    error = relative_l2_norm(u, ua)
    errors.append(error)
# Out:
# 11
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-4579de864883> in <module>()
#       7     y = x.copy()
#       8     u0 = numpy.zeros((nx, ny))
# ----> 9     u0[-1, :] = numpy.sin(1.5 * numpy.pi * x / Lx)
#      10     u = laplace2d_jacobi_neumann(u0, rtol=1e-8)[0]
#      11     ua = analytical_solution(x, y, Lx, Lx)
#
# ValueError: could not broadcast input array from shape (11) into shape (41)

# %%
pyplot.figure(figsize=(6.0, 6.0))
pyplot.grid()
dx_values = Lx / (numpy.array(nx_values) - 1)
pyplot.loglog(dx_values, errors,
              color='black', linestyle='--', linewidth=2, marker='o')
pyplot.axis('equal');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b85b3af0f86e> in <module>()
#       3 dx_values = Lx / (numpy.array(nx_values) - 1)
#       4 pyplot.loglog(dx_values, errors,
# ----> 5               color='black', linestyle='--', linewidth=2, marker='o')
#       6 pyplot.axis('equal');
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in loglog(*args, **kwargs)
#    3228                       mplDeprecation)
#    3229     try:
# -> 3230         ret = ax.loglog(*args, **kwargs)
#    3231     finally:
#    3232         ax._hold = washold
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in loglog(self, *args, **kwargs)
#    1671         b = self._hold
#    1672         self._hold = True  # we've already processed the hold
# -> 1673         l = self.plot(*args, **kwargs)
#    1674         self._hold = b  # restore the hold
#    1675
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (0,)
